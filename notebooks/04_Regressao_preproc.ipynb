# %% [markdown]
# # Construindo o Modelo de Regressão
#
# Nesse Notebook, foi realizada a construção inicial do modelo e feitos os primeiros testes de quais transformações possuem maior efetividade.
#
# Regressor: Linear
#
# Foram testadas 3 estratégias de preprocessamento das entradas do Modelo:
#
# 1. Transformar apenas as colunas categóricas (não ordenadas - OneHotEncoder e ordenadas - OrdinalEncoder)
#
# 2. Tranformar as categóricas (não ordenadas e ordenadas) e ajuste de escala em todas as numéricas (Robust Scaler).
#
# 3. Transformar  as categóricas (não ordenadas e ordenadas), coordenadas e idade das casas (quase normal) com ajuste simples de escala (Standard Scaler) e as demais numéricas ajustando a distribuição para próxima a normal (Power Transformer).
#
# Para a coluna Target, foram testadas 3 estratégias:
#
# 1. Sem transformação
#
# 2. Tratar com Power Transformer - uma forma de normalização
#
# 3. Tratar com Quantile Transformer - outra forma de normalização
#
# Após a definição do melhor modelo (combinação de teste das estratégicas de preprocessamento de entradas e target), será feita a comparação de tempo de execução e métricas de erro com Dummy Regressor (prevê que o preço será a média do target), LinearRegression com transformação apenas nas categóricas e melhor modelo.

# %% [markdown]
# # Importar Bibliotecas e dados

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS, PASTA_IMAGENS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  object
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: float32(6), int16(4), int32(1), int64(1), int8(1), object(1)
# memory usage: 909.2+ KB

# %% [markdown]
# # Definição dos Modelos

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)

colunas_robust_scaler
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object')

# %%
colunas_standard_scaler = ["longitude", "latitude", "housing_median_age"]

colunas_power_transformer = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder + colunas_standard_scaler)

colunas_power_transformer
# Out:
# Index(['bedrooms_per_room', 'households', 'median_income', 'population',
#        'population_per_household', 'rooms_per_household', 'total_bedrooms',
#        'total_rooms'],
#       dtype='object')

# %%
preprocessamento_categoricas = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
    ],
    remainder="passthrough",
)

preprocessamento_simples = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
        ("robust_scaler", RobustScaler(), colunas_robust_scaler),
    ],
)

preprocessamento_completo = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
        ("scaler", StandardScaler(), colunas_standard_scaler),
        ("power_transformer", PowerTransformer(), colunas_power_transformer)
    ],
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
param_grid = {
    "regressor__preprocessor": [preprocessamento_categoricas, preprocessamento_simples, preprocessamento_completo],
    "transformer": [None, PowerTransformer(), QuantileTransformer(output_distribution="normal")]
}

# %% [markdown]
# # Encontrando o melhor Modelo

# %%
grid_search = grid_search_cv_regressor(
    regressor=LinearRegression(),
    preprocessor=preprocessamento_completo,
    target_transformer=PowerTransformer(),
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('scaler',
#                                                                                                               StandardScaler(),
#                                                                                                               ['longitude',
#                                                                                                                'latitude',
#                                                                                                                'housi...
#                                                                                       Index(['bedrooms_per_room', 'households', 'median_income', 'population',
#        'population_per_household', 'rooms_per_household', 'total_bedrooms',
#        'total_rooms'],
#       dtype='object'))])],
#                          'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('scaler',
#                                                                                                               StandardScaler(),
#                                                                                                               ['longitude',
#                                                                                                                'latitude',
#                                                                                                                'housi...
#                                                                                       Index(['bedrooms_per_room', 'households', 'median_income', 'population',
#        'population_per_household', 'rooms_per_household', 'total_bedrooms',
#        'total_rooms'],
#       dtype='object'))])],
#                          'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor': ColumnTransformer(transformers=[('ordinal_encoder', OrdinalEncoder(),
#                                   ['median_income_cat']),
#                                  ('one_hot', OneHotEncoder(drop='first'),
#                                   ['ocean_proximity']),
#                                  ('robust_scaler', RobustScaler(),
#                                   Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#         'longitude', 'median_income', 'population', 'population_per_household',
#         'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#        dtype='object'))]),
#  'transformer': QuantileTransformer(output_distribution='normal')}

# %% [markdown]
# O melhor Modelo combina a Estratégia 2 de Pré-Processamento das variáveis de entrada com a Estratégia 3 de Transformação de Target.

# %%
grid_search.best_score_
# Out:
# np.float64(-54417.29591619371)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                          coeficiente
# robust_scaler__latitude                    -1.078752
# robust_scaler__longitude                   -1.065953
# one_hot__ocean_proximity_INLAND            -0.454431
# robust_scaler__population_per_household    -0.233935
# one_hot__ocean_proximity_NEAR BAY          -0.203118
# robust_scaler__total_rooms                 -0.100154
# robust_scaler__total_bedrooms              -0.078152
# one_hot__ocean_proximity_NEAR OCEAN        -0.059868
# robust_scaler__population                  -0.032203
# ordinal_encoder__median_income_cat          0.036512
# robust_scaler__housing_median_age           0.118224
# robust_scaler__rooms_per_household          0.178008
# robust_scaler__bedrooms_per_room            0.242376
# robust_scaler__households                   0.272014
# robust_scaler__median_income                0.795109

# %%
plot_coeficientes(coefs)

# %% [markdown]
# Observamos que as coordenadas longitude e latitude (quanto mais perto do sudoeste, maior o preço da casa), assim como a renda média (quanto maior, maior o preço da casa) são as variáveis que mais afetam o modelo, o que é coerente com a análise exploratória.

# %% [markdown]
# # Comparando o Melhor Modelo com referência

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento_categoricas,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_grid_search": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}


resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                            model  fit_time score_time   test_r2  \
# 0                 DummyRegressor  0.013509   0.005234 -0.000081
# 1                 DummyRegressor  0.002066        0.0 -0.000146
# 2                 DummyRegressor       0.0   0.009273 -0.001737
# 3                 DummyRegressor    0.0028      0.002 -0.000101
# 4                 DummyRegressor     0.002   0.002002 -0.000114
# 5               LinearRegression  0.003034   0.021756  0.682162
# 6               LinearRegression  0.015004   0.006001   0.66999
# 7               LinearRegression  0.009215        0.0  0.649247
# 8               LinearRegression   0.02769        0.0  0.669873
# 9               LinearRegression   0.01563        0.0  0.669023
# 10  LinearRegression_grid_search  0.031249   0.015627  0.692222
# 11  LinearRegression_grid_search  0.020748   0.025329  0.677951
# 12  LinearRegression_grid_search  0.068088   0.018881   0.65421
# 13  LinearRegression_grid_search  0.032523   0.059855  0.684068
# 14  LinearRegression_grid_search  0.067739   0.016221  0.682951
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.018742
# 1                 -75787.787194                    -95217.629397     0.002066
# 2                 -76753.598961                    -96253.253947     0.009273
# 3                 -76837.804811                    -95983.885799       0.0048
# 4                 -76617.245449                    -96182.764729     0.004002
# 5                 -39855.690921                    -54254.958115      0.02479
# 6                 -40272.565406                    -54695.230224     0.021005
# 7                 -42178.059246                    -56955.988686     0.009215
# 8                 -40806.492452                     -55146.31876      0.02769
# 9                 -40788.496555                    -55331.351171      0.01563
# 10                 -37797.79937                    -53389.434753     0.046876
# 11                -38289.147231                    -54031.471522     0.046077
# 12                -40273.399415                    -56551.573113     0.086968
# 13                -38600.882459                    -53947.707913     0.092378
# 14                -38406.493457                    -54154.612017     0.083961

# %%
df_resultados.groupby("model").mean()
# Out:
#                               fit_time score_time   test_r2  \
# model
# DummyRegressor                0.004075   0.003702 -0.000436
# LinearRegression              0.014114   0.005551  0.668059
# LinearRegression_grid_search  0.044069   0.027183  0.678281
#
#                              test_neg_mean_absolute_error  \
# model
# DummyRegressor                              -76702.495836
# LinearRegression                            -40780.260916
# LinearRegression_grid_search                -38673.544386
#
#                              test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                  -95975.447913     0.007776
# LinearRegression                                -55276.769391     0.019666
# LinearRegression_grid_search                    -54414.959863     0.071252

# %%
df_resultados.groupby("model").mean().sort_values(by="test_neg_root_mean_squared_error")
# Out:
#                               fit_time score_time   test_r2  \
# model
# DummyRegressor                0.004075   0.003702 -0.000436
# LinearRegression              0.014114   0.005551  0.668059
# LinearRegression_grid_search  0.044069   0.027183  0.678281
#
#                              test_neg_mean_absolute_error  \
# model
# DummyRegressor                              -76702.495836
# LinearRegression                            -40780.260916
# LinearRegression_grid_search                -38673.544386
#
#                              test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                  -95975.447913     0.007776
# LinearRegression                                -55276.769391     0.019666
# LinearRegression_grid_search                    -54414.959863     0.071252

# %%
plot_comparar_metricas_modelos(df_resultados)

# %% [markdown]
# O melhor modelo se mostrou mais eficaz que o Linear Regression sem gastar muito tempo de treinamento e teste (0.04s vs 0.025s), e por isso será nossa referência para os próximos testes.

# %% [markdown]
# # Avaliação da distribuição de erro do Modelo

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)

# %% [markdown]
# A maior frequência de resíduo próximo a zero nos testes mostra a eficácia do modelo. Os erros maiores ocorrem para casas mais caras, com erro para menos (valor real maior que o previsto para os maiores erros). Isso acontece pois temos mais registros na base com casas de menor a médio preço do que de preços exorbitantes, como é possível notar nos 2 gráficos a direita.
