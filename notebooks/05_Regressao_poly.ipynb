# %% [markdown]
# # Refinando o Modelo de Regressão - Features Polinomiais
#
# Nesse Notebook, foi realizado o refino do modelo testando grandezas de segundo e terceiro grau nas variáveis de entrada.
#
# Regressor: Linear
#
# Graus dos polinomios - 1, 2 e 3
#
# Todo o processo desenvolvido na etapa anterior foi repetida.

# %% [markdown]
# # Importar Bibliotecas e dados

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  object
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: float32(6), int16(4), int32(1), int64(1), int8(1), object(1)
# memory usage: 909.2+ KB

# %%
df['ocean_proximity'] = df['ocean_proximity'].astype('category')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %% [markdown]
# # Definição dos Modelos

# %%
coluna_target = ['median_house_value']

coluna_one_hot_encoder = ['ocean_proximity']

coluna_ordinal_encoder = ['median_income_cat']

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)

colunas_robust_scaler
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object')

# %%
pipeline_robust = Pipeline(steps=[
    ("robust_scaler", RobustScaler()),
    ("poly", PolynomialFeatures(degree=1, include_bias=False))
])

preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot_encoder", OneHotEncoder(drop='first'), coluna_one_hot_encoder),
        ("robust_scaler_poly", pipeline_robust, colunas_robust_scaler) # Std menos sensível a outliers
    ],
    remainder='passthrough'
)

# %%
X = df.drop(columns=coluna_target)

y = df[coluna_target]

# %% [markdown]
# # Encontrando o melhor Modelo

# %%
param_grid = { 
    "regressor__preprocessor__robust_scaler_poly__poly__degree": [1, 2, 3],
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=LinearRegression(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution='normal'),
    param_grid=param_grid
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pip...
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object'))])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pip...
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object'))])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3}

# %% [markdown]
# Grau 3 apresentou o menor erro, vamos avaliar agora os scores e os principais coefientes

# %%
grid_search.best_score_
# Out:
# np.float64(-51145.84344886369)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_['reg'].coef_,
    grid_search.best_estimator_.regressor_['preprocessor'].get_feature_names_out(),
)

coefs
# Out:
#                                                       coeficiente
# robust_scaler_poly__longitude total_rooms          -313924.292082
# robust_scaler_poly__housing_median_age total_rooms -227347.580379
# robust_scaler_poly__latitude total_rooms           -217657.998778
# robust_scaler_poly__rooms_per_household total_b... -214517.420832
# robust_scaler_poly__latitude population_per_hou... -208340.625630
# ...                                                           ...
# robust_scaler_poly__households                      163652.143638
# robust_scaler_poly__longitude population            170453.655311
# robust_scaler_poly__latitude population rooms_p...  209693.842518
# robust_scaler_poly__bedrooms_per_room households    220478.504411
# robust_scaler_poly__latitude population             228572.483418
#
# [367 rows x 1 columns]

# %% [markdown]
# São 367 coeficientes diferentes, vamos olhar apenas os abaixo de -100.000 e acima de 100.000 - escala aumentou muito por ter relação de 3º grau

# %%
# somente os coeficientes mais relevantes
plot_coeficientes(coefs[~coefs['coeficiente'].between(-100_000,100_000)])

# %% [markdown]
# Agora temos variáveis compostas influenciando o modelo, sendo as de maiores coeficientes a de latitude com população e longitude com maior número de quartos. Essas relações, apesar de mais dificeis de compreender, permitem mais opções de refino por parte do modelo.

# %% [markdown]
# # Comparando o Melhor Modelo com referência

# %%
regressors = {
    "DummyRegressor" : {
        "preprocessor" : None,
        "regressor" : DummyRegressor(strategy='mean'),
        "target_transformer" : None,
    },
        "LinearRegression" : {
        "preprocessor" : preprocessamento,
        "regressor" : LinearRegression(),
        "target_transformer" : None,
    },
        "LinearRegression_target_quantile" : {
        "preprocessor" : preprocessamento,
        "regressor" : LinearRegression(),
        "target_transformer" : QuantileTransformer(output_distribution='normal'),
    },
        "LinearRegression_poly" : {
        "preprocessor" : grid_search.best_estimator_.regressor_['preprocessor'],
        "regressor" : grid_search.best_estimator_.regressor_['reg'],
        "target_transformer" : grid_search.best_estimator_.transformer_,
    },

}

resultados = {
    nome_modelo : treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                                model  fit_time score_time   test_r2  \
# 0                     DummyRegressor  0.002991      0.004 -0.000081
# 1                     DummyRegressor  0.003002   0.002998 -0.000146
# 2                     DummyRegressor  0.003002      0.003 -0.001737
# 3                     DummyRegressor  0.001998   0.002006 -0.000101
# 4                     DummyRegressor  0.002001   0.002007 -0.000114
# 5                   LinearRegression  0.023995   0.008004  0.682162
# 6                   LinearRegression  0.024997   0.008002   0.66999
# 7                   LinearRegression  0.024006   0.007001  0.649247
# 8                   LinearRegression  0.022005   0.007001  0.669873
# 9                   LinearRegression  0.022008   0.006999  0.669023
# 10  LinearRegression_target_quantile   0.02702   0.009002  0.691715
# 11  LinearRegression_target_quantile  0.029018   0.007991  0.677863
# 12  LinearRegression_target_quantile  0.026021   0.007003  0.653687
# 13  LinearRegression_target_quantile  0.026993   0.009015   0.68398
# 14  LinearRegression_target_quantile  0.027988   0.007002  0.683209
# 15      LinearRegression_grid_search  0.225052   0.021004  0.727639
# 16      LinearRegression_grid_search  0.232054   0.022004  0.719363
# 17      LinearRegression_grid_search  0.284064   0.022003  0.691174
# 18      LinearRegression_grid_search  0.263063   0.028003  0.724153
# 19      LinearRegression_grid_search  0.255059   0.023005  0.717649
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.006991
# 1                 -75787.787194                    -95217.629397        0.006
# 2                 -76753.598961                    -96253.253947     0.006002
# 3                 -76837.804811                    -95983.885799     0.004004
# 4                 -76617.245449                    -96182.764729     0.004007
# 5                 -39855.690996                    -54254.958188     0.031998
# 6                 -40272.565467                    -54695.230283     0.032999
# 7                  -42178.05929                    -56955.988706     0.031007
# 8                 -40806.492497                    -55146.318803     0.029006
# 9                 -40788.496497                     -55331.35106     0.029007
# 10                -37803.516783                     -53433.45235     0.036022
# 11                -38312.682921                    -54038.843556     0.037009
# 12                -40299.231077                    -56594.346955     0.033023
# 13                -38584.273291                    -53955.246133     0.036008
# 14                -38419.618577                    -54132.562903      0.03499
# 15                -34672.492398                    -50223.777169     0.246056
# 16                -35020.242857                    -50438.070947     0.254057
# 17                -37373.279315                     -53443.54681     0.306067
# 18                -35200.146837                    -50409.281819     0.291066
# 19                 -35579.04853                    -51105.405747     0.278064

# %%
plot_comparar_metricas_modelos(df_resultados)

# %% [markdown]
# Tivemos um aumento considerável no tempo de processamento (fit e score), porém ainda é um tempo baixo (0.28s em relação a 0.04s), com diminuição no erro. Ainda vamos tentar refinar mais a questão do erro.

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, eng_formatter=True)

# %% [markdown]
# A maior frequência de resíduo próximo a zero nos testes mostra a eficácia do modelo. Os erros maiores ocorrem para casas mais caras, com erro para menos (valor real maior que o previsto para os maiores erros). Isso acontece pois temos mais registros na base com casas de menor a médio preço do que de preços exorbitantes, como é possível notar nos 2 gráficos a direita.
#
# Comparando com o resultado anterior, não foi possível observar melhora
